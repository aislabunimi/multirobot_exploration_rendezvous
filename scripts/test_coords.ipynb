# %%
import coords_parser as cp
import matplotlib.pyplot as plt

# %%
list(zip([1,2,3,4],['a','b','c']))
# Out:
# [(1, 'a'), (2, 'b'), (3, 'c')]

# %%
areas = cp.parse_from_file('../semantic_coords/map23.coords')
list(zip(*areas[0].polygon.exterior.xy))
# Out:
# [(-0.14, 11.14),
#  (2.11, 10.63),
#  (9.41, 10.67),
#  (10.47, 9.96),
#  (17.89, 10.07),
#  (18.99, 11.06),
#  (19.19, 25.54),
#  (16.98, 24.0),
#  (17.02, 16.82),
#  (16.86, 15.2),
#  (17.61, 14.3),
#  (17.69, 14.06),
#  (15.52, 13.11),
#  (15.68, 12.56),
#  (13.9, 11.77),
#  (13.83, 12.4),
#  (9.13, 11.69),
#  (5.58, 11.85),
#  (1.6, 12.95),
#  (-0.18, 14.14),
#  (-0.14, 11.14)]
