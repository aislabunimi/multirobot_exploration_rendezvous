# %%
import stats
import numpy as np
import matplotlib.pyplot as plt

path = '../data/data_test.db'
comma = lambda x: str(x).replace(".",",")

# %%
# plt.subplots(dpi=200)
# ex = 10486
# SR = stats.SingleRun(path, ex, real_map='office_big')
# perc = SR.get_perc_area(check_map=True, check_pos=True)
# time = SR.get_rendezvous_time()
# print(f"{ex}\t{comma(time)}\t{comma(perc)}")

# %%
TS_office2_3 = stats.TestSet(
    path,
    {
        'sem1_15'     : [10130,10131,10132,10133,10134,10135,10136,10137,10138,10139],
        'sem1_30'     : [10043,10044,10045,10046,10047,10048,10049,10050,10052,10055],
        'sem1_50'     : [10094,10095,10096,10097,10099,10100,10104,10105,10106,10116],
        'sem2'        : [10057,10058,10059,10060,10061,10062,10063,10064,10065,10067],
        'sem1_50_nID' : [10181,10180,10179,10178,10183,10184,10185,10186,10187,10188],
        'sem1_50_2R'  : [10205,10206,10207,10208,10209,10213,10214,10215,10216,10217],
        'sem1_50_3R'  : [10219,10220,10221,10222,10223,10224,10225,10228,10230,10231],
        'fbe-bt-2R'   : [10264,10265,10266,10267,10268,10269,10270,10271,10272,10273],
        'fbe-bt-3R'   : [10309,10310,10311,10314,10315,10316,10317,10318,10319,10320],
        'fbe-2R'      : [10340,10341,10342,10343,10344,10345,10346,10347,10348,10349],
        'fbe-3R'      : [10385,10386,10387,10389,10390,10391,10392,10393,10394,10395]
    },
    'office_2'
)
TS_office2_3.get_boxplot_times()

# %%
TS_office2_3.get_boxplot_perc_areas()

# %%
#plt.subplots(dpi=350)
#stats.SingleRun(path,10231,real_map="office_2").get_perc_area(check_map=True, check_pos=True)

# %% [markdown]
# # BIG OFFICE

# %%
TS_big_3 = stats.TestSet(
    path,
    {
        'sem1_15'     : [10140,10141,10142,10143,10144,10145,10146,10148,10149,10150],
        'sem1_30'     : [10006,10007,10010,10015,10017,10018,10019,10032,10033,10037],
        'sem1_50'     : [10101,10102,10104,10110,10114,10115,10117,10118,10119,10129],
        'sem2'        : [10070,10071,10072,10078,10079,10080,10083,10085,10088,10091],
        'sem1_50_nID' : [10189,10191,10195,10196,10197,10198,10199,10200,10203,10204],
        'sem1_50_2R'  : [10232,10233,10236,10237,10238,10239,10240,10241,10242,10243],
        'sem1_50_3R'  : [10244,10247,10248,10249,10251,10252,10254,10257,10258,10259],
        'fbe-bt-2R'   : [10277,10279,10280,10282,10287,10301,10302,10305,10306,10307],
        'fbe-bt-3R'   : [10322,10325,10326,10328,10330,10332,10335,10336,10337,10338],
        'fbe-2R'      : [10355,10356,10357,10359,10361,10362,10365,10366,10368,10369],
        'fbe-3R'      : [10403,10405,10407,10409,10411,10413,10415,10418,10419,10420]
    },
    'office_big'
)
TS_big_3.get_boxplot_times()

# %%
TS_big_3.get_boxplot_perc_areas()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
