# %%
import stats
from stats import SingleRun
import pandas as pd
import sqlite3

# %%
path = '../data/data_test.db'

# %%
SR = SingleRun(path,37,real_map='office_big')
print(str(SR.get_rendezvous_time()).replace('.',','))
print(str(SR.get_perc_area(check_map=True, check_pos=True)).replace('.',','))
# Out:
# 1467,851999999999
# 0,6498893207977718
