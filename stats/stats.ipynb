# %%
import stats
from stats import SingleRun, TestSet
import pandas as pd
import sqlite3

# %%
path = '../data/data_test.db'

# %%
run = 95
SR = SingleRun(path,run,real_map='office_2')
print(str(SR.get_rendezvous_time()).replace('.',','),'\t',str(SR.get_perc_area(check_map=True, check_pos=True)).replace('.',','))
# Out:
# 139,03300000000002 	 0,44366448634886463

# %%
TS_E40_3 = stats.TestSet(
    path,
    {'sem1': [7,12,14,15,19,21,22,23,26,27]},
    'e40'
)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 TS_E40_3 = stats.TestSet(
#       2     path,
#       3     {'sem1': [7,12,14,15,19,21,22,23,26,27]},
#       4     'e40'
#       5 )
#
# File ~/Documents/Tellaroli/test_ws/src/journal_rendezvous/stats/stats.py:313, in TestSet.__init__(self, db_path, test_set, map_name, verbose)
#     311 self.data = {method:[SingleRun(db_path,ts,real_map=map_name,verbose=verbose) for ts in test_set[method]] for method in test_set}
#     312 if any([len(set([sr.get_robot_nr() for sr in self.data[meth]]))!=1 for meth in self.data]):
# --> 313     raise Exception('Le run non hanno lo stesso numero di robot')
#     314 self.robot_nr = self.data[self.methods[0]][0].get_robot_nr()
#
# Exception: Le run non hanno lo stesso numero di robot
